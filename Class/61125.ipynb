# %%
import re
txt = "The rain of 7 oct 25 in spain"
s = re.split(r"\s", txt)
d = re.split(r"\d", txt)
S = re.split(r"\S", txt)
print(d)
print(s)
print(S)
# Out:
# ['The rain of ', ' oct ', '', ' in spain']
# ['The', 'rain', 'of', '7', 'oct', '25', 'in', 'spain']
# ['', '', '', ' ', '', '', '', ' ', '', ' ', ' ', '', '', ' ', '', ' ', '', ' ', '', '', '', '', '']
