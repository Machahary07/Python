# %%
# WAF that takes length and breadth of a rectangle & returns its perimeter and area
def rect(l, b):
    a = l * b
    p = 2 * (l + b)
    return a, p

a, p = rect(2, 3)
print("Area:", a, "Perimeter:", p)
# Out:
# Area: 6 Perimeter: 10

# %%
#WAF that takes radius of a circle & returns its circumference and area without import math
def circle(r):
    pi = 3.14
    a = pi * r * r
    c = 2 * pi * r
    return a, c 

a, c = circle(7)
print("Area:", a, "Circumference:", c)
# Out:
# Area: 153.86 Circumference: 43.96

# %%
# WAF to find the nth fibonacci number using recursion
def fib(n):
    if n <= 1:
        return n
    else:
        return fib(n-1) + fib(n-2)

fib(3)
# Out:
# 2

# %%
# WAF that takes a list of numbers and returns two lists - one containing odd numbers and the other containing even numbers
def odd_even(lst):
    odd = []
    even = []
    for i in lst:
        if i % 2 == 0:
            even.append(i)
        else:
            odd.append(i)
    return odd, even

odd, even = odd_even([1, 2, 3, 4, 5, 6])
print("Odd:", odd, "Even:", even)
# Out:
# Odd: [1, 3, 5] Even: [2, 4, 6]

# %%
#WAF to count vowels in a given string
def count_vowels(s):
    vowels = 'aeiouAEIOU'
    count = 0
    for char in s:
        if char in vowels:
            count += 1
    return count

print(count_vowels("Hello, World!"))
# Out:
# 3

# %%
#WAF to check if a string is a palindrome
def is_pal(s: str)-> bool:
    return s == s[::-1]

def is_pal_int(n: int) -> bool:
    o, rev = n, 0
    while n > 0:
        rev = rev * 10 + n % 10
        n //= 10
    return o == rev

print(is_pal("woo"))
print(is_pal("madam"))
print(is_pal("1234321"))
print(is_pal("1234"))

print(is_pal_int(123))
print(is_pal_int(12321))
# Out:
# False
# True
# True
# False
# False
# True

# %%
#WAF that accepts a sentence and returns the word with the maximum length
def max_l_word(s: str) -> str:
    return max(s.split(), key=len)

print(max_l_word("Hello World from Python"))
# Out:
# Python

# %%
#WAF that acceps a list of numbers and returns the second largest number
def second_largest(lst: list) -> int:
    if len(lst) < 2:
        raise ValueError("List must contain at least two elements")
    unique_lst = list(set(lst))  # Remove duplicates
    unique_lst.sort()
    return unique_lst[-2]  # Second largest
print(second_largest([1, 2, 3, 4, 5, 5, 4, 3, 2, 1]))
# Out:
# 4

# %%
#WAF that takes an int n & returns the factorial of n & the number of digits in that factorial
def fact():
    n = int(input("Enter a number: "))
    f = 1
    for i in range(2, n + 1):
        f *= i
    return f, len(str(f))
print(fact())
# Out:
# (720, 3)

# %%
def oddeven(num):
    return num%2==0

a=int(input("Enter Number"))
print("True for even, False for odd")
oddeven(a)
# Out:
# True for even, False for odd
# False

# %%
#create tuples, appened 2 tuples
def create_and_append_tuples(t1, t2):
    return t1 + t2

print(create_and_append_tuples((1, 2, 3), (4, 5, 6)))

#unpack tuples and print
def unpack_and_print(t):
    a, b, c = t
    print("First:", a)
    print("Second:", b)
    print("Third:", c)

unpack_and_print((10, 20, 30))
# Out:
# (1, 2, 3, 4, 5, 6)
# First: 10
# Second: 20
# Third: 30

# %%
#WAF to find the sum of all elements in a tuple
def sum_of_tuple(t):
    return sum(t)
print(sum_of_tuple((1, 2, 3, 4, 5)))
# Out:
# 15

# %%
#WAP making dictionary and an inner dictionary
dct={
    'name': 'John',
    'age': 30,
    'city': 'New York',
    'job': {
        'title': 'Software Engineer',
        'company': 'ABC Company'
    }
}
print(dct)
# Out:
# {'name': 'John', 'age': 30, 'city': 'New York', 'job': {'title': 'Software Engineer', 'company': 'ABC Company'}}

# %%
#function for turning tuple to list and reversing it
def tuple_to_reversed_list(t):
    lst = list(t)
    return lst[::-1]

print(tuple_to_reversed_list((1, 2, 3, 4, 5)))
# Out:
# [5, 4, 3, 2, 1]

# %%
#WAP to print default parameters
def default_parameters(a=10, b=20):
    print("a:", a)
    print("b:", b)

default_parameters()



def greet(name="guest", msg="welcome"):
    print(f"hello {name}, {msg}")

greet()
greet("Biki","lob you")
# Out:
# a: 10
# b: 20
# hello guest, welcome
# hello Biki, lob you
