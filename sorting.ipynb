# %%
#insertion sort

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

a = [5, 2, 9, 1, 5, 6]
print("Before sorting:", a)
sorted_a = insertion_sort(a)
print("After sorting:", sorted_a)
# Out:
# Before sorting: [5, 2, 9, 1, 5, 6]
# After sorting: [1, 2, 5, 5, 6, 9]

# %%
#Selection Sort

def selection_sort(arr):
    for i in range(len(arr)):
        min_index = i
        for j in range(i + 1, len(arr)):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

a = [5, 2, 9, 1, 5, 6]
print("Before sorting:", a)
sorted_a = selection_sort(a)
print("After sorting:", sorted_a)
# Out:
# Before sorting: [5, 2, 9, 1, 5, 6]
# After sorting: [1, 2, 5, 5, 6, 9]

# %%
#Bubble Sort

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

a = [5, 2, 9, 1, 5, 6]
print("Before sorting:", a)
sorted_a = bubble_sort(a)
print("After sorting:", sorted_a)
# Out:
# Before sorting: [5, 2, 9, 1, 5, 6]
# After sorting: [1, 2, 5, 5, 6, 9]

# %%
#merge sort

def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i, j, k = 0, 0, 0
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1
    return arr

a = [(80, 'Charlie'), (92, 'Alice'), (82, 'Bob')]
print("Before sorting:", a)
sorted_a = merge_sort(a)
print("After sorting:", sorted_a)
# Out:
# Before sorting: [(80, 'Charlie'), (92, 'Alice'), (82, 'Bob')]
# After sorting: [(80, 'Charlie'), (82, 'Bob'), (92, 'Alice')]

# %%
#radix sort

def radix_sort(arr):
    max_num = max(arr)
    exp = 1
    while max_num // exp > 0:
        counting_sort(arr, exp)
        exp *= 10
    return arr

def counting_sort(arr, exp):
    n = len(arr)
    output = [0] * n
    count = [0] * 10

    for i in range(n):
        index = arr[i] // exp % 10
        count[index] += 1
    for i in range(1, 10):
        count[i] += count[i - 1]
    for i in range(n - 1, -1, -1):
        index = arr[i] // exp % 10
        output[count[index] - 1] = arr[i]
        count[index] -= 1
    for i in range(n):
        arr[i] = output[i]
    return arr

a = [3456, 1201, 8990, 4321, 1111, 7823, 5543, 2198]
print("Before sorting:", a)
sorted_a = radix_sort(a)
print("After sorting:", sorted_a)
# Out:
# Before sorting: [3456, 1201, 8990, 4321, 1111, 7823, 5543, 2198]
# After sorting: [1111, 1201, 2198, 3456, 4321, 5543, 7823, 8990]
